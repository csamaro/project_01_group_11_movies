# %%
import pandas as pd

# %%
merged = pd.read_csv("output_data/merged.csv")

# %%
netflix = pd.read_csv("resources/NetflixFilms_2018-2022.csv")

# %%
netflix["Format"] = "netflix"
netflix2 = netflix.loc[:,["Title","Format"]]
netflix2
# Out:
#                                  Title   Format
# 0                       The Polka King  netflix
# 1                         Step Sisters  netflix
# 2                       The Open House  netflix
# 3          A Futile and Stupid Gesture  netflix
# 4              The Cloverfield Paradox  netflix
# ..                                 ...      ...
# 593                     Private Lesson  netflix
# 594           A Not So Merry Christmas  netflix
# 595  Glass Onion: A Knives Out Mystery  netflix
# 596        A Night at the Kindergarten  netflix
# 597                        White Noise  netflix
#
# [598 rows x 2 columns]

# %%
merged2 = pd.merge(merged,netflix2,on="Title",how="left")

# %%
merged2
# Out:
#                        Title  Year     Released  Runtime  \
# 0    Insidious: The Last Key  2018  05 Jan 2018  103 min
# 1           The Strange Ones  2017  05 Jan 2018   81 min
# 2                   Stratton  2017  05 Jan 2018   95 min
# 3              Sweet Country  2017  06 Apr 2018  113 min
# 4               The Commuter  2018  12 Jan 2018  104 min
# ..                       ...   ...          ...      ...
# 972                 Free Guy  2021  13 Aug 2021  115 min
# 973                  Respect  2021  13 Aug 2021  145 min
# 974                  Beckett  2021  13 Aug 2021  110 min
# 975          Don't Breathe 2  2021  13 Aug 2021   98 min
# 976                     CODA  2021  13 Aug 2021  111 min
#
#                          Genre  \
# 0    Horror, Mystery, Thriller
# 1              Drama, Thriller
# 2             Action, Thriller
# 3      Adventure, Crime, Drama
# 4    Action, Mystery, Thriller
# ..                         ...
# 972  Action, Adventure, Comedy
# ...

# %%
merged2["Format"] = merged2["Format"].fillna("not_netflix")

# %%
merged2
# Out:
#                        Title  Year     Released  Runtime  \
# 0    Insidious: The Last Key  2018  05 Jan 2018  103 min
# 1           The Strange Ones  2017  05 Jan 2018   81 min
# 2                   Stratton  2017  05 Jan 2018   95 min
# 3              Sweet Country  2017  06 Apr 2018  113 min
# 4               The Commuter  2018  12 Jan 2018  104 min
# ..                       ...   ...          ...      ...
# 972                 Free Guy  2021  13 Aug 2021  115 min
# 973                  Respect  2021  13 Aug 2021  145 min
# 974                  Beckett  2021  13 Aug 2021  110 min
# 975          Don't Breathe 2  2021  13 Aug 2021   98 min
# 976                     CODA  2021  13 Aug 2021  111 min
#
#                          Genre  \
# 0    Horror, Mystery, Thriller
# 1              Drama, Thriller
# 2             Action, Thriller
# 3      Adventure, Crime, Drama
# 4    Action, Mystery, Thriller
# ..                         ...
# 972  Action, Adventure, Comedy
# ...

# %%
merged2["Format"].value_counts()
# Out:
# not_netflix    869
# netflix        108
# Name: Format, dtype: int64

# %%
merged2["Released"] = merged2["Released"].astype("datetime64")
merged2["BoxOffice"]  = merged2["BoxOffice"].str.replace("$","")
merged2["BoxOffice"]  = merged2["BoxOffice"].str.replace(",","")
merged2["BoxOffice"] = merged2["BoxOffice"].astype("float")

# %%
merged2.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 977 entries, 0 to 976
# Data columns (total 15 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   Title       977 non-null    object
#  1   Year        977 non-null    int64
#  2   Released    975 non-null    datetime64[ns]
#  3   Runtime     975 non-null    object
#  4   Genre       976 non-null    object
#  5   Awards      805 non-null    object
#  6   Metascore   878 non-null    float64
#  7   imdbRating  971 non-null    float64
#  8   imdbVotes   972 non-null    object
#  9   imdbID      977 non-null    object
#  10  BoxOffice   590 non-null    float64
#  11  Language    974 non-null    object
#  12  budget_max  917 non-null    float64
#  13  budget_min  917 non-null    float64
#  14  Format      977 non-null    object
# dtypes: datetime64[ns](1), float64(5), int64(1), object(8)
# memory usage: 122.1+ KB

# %%
merged2
# Out:
#                        Title  Year   Released  Runtime  \
# 0    Insidious: The Last Key  2018 2018-01-05  103 min
# 1           The Strange Ones  2017 2018-01-05   81 min
# 2                   Stratton  2017 2018-01-05   95 min
# 3              Sweet Country  2017 2018-04-06  113 min
# 4               The Commuter  2018 2018-01-12  104 min
# ..                       ...   ...        ...      ...
# 972                 Free Guy  2021 2021-08-13  115 min
# 973                  Respect  2021 2021-08-13  145 min
# 974                  Beckett  2021 2021-08-13  110 min
# 975          Don't Breathe 2  2021 2021-08-13   98 min
# 976                     CODA  2021 2021-08-13  111 min
#
#                          Genre  \
# 0    Horror, Mystery, Thriller
# 1              Drama, Thriller
# 2             Action, Thriller
# 3      Adventure, Crime, Drama
# 4    Action, Mystery, Thriller
# ..                         ...
# 972  Action, Adventure, Comedy
# 973    Biography, Drama, Music
# ...

# %%
merged3 = merged2.drop(["Year", "budget_min"], axis=1)

# %%
merged3
# Out:
#                        Title   Released  Runtime                      Genre  \
# 0    Insidious: The Last Key 2018-01-05  103 min  Horror, Mystery, Thriller
# 1           The Strange Ones 2018-01-05   81 min            Drama, Thriller
# 2                   Stratton 2018-01-05   95 min           Action, Thriller
# 3              Sweet Country 2018-04-06  113 min    Adventure, Crime, Drama
# 4               The Commuter 2018-01-12  104 min  Action, Mystery, Thriller
# ..                       ...        ...      ...                        ...
# 972                 Free Guy 2021-08-13  115 min  Action, Adventure, Comedy
# 973                  Respect 2021-08-13  145 min    Biography, Drama, Music
# 974                  Beckett 2021-08-13  110 min       Action, Crime, Drama
# 975          Don't Breathe 2 2021-08-13   98 min      Action, Crime, Horror
# 976                     CODA 2021-08-13  111 min       Comedy, Drama, Music
#
# ...

# %%
x = merged3["BoxOffice"].isna().sum()

# %%
x
# Out:
# 387

# %%
merged3.to_csv("output_data/merged2.csv")
